# %%
import urllib
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
itas2010 = 'http://www.itas2010.iitp.ru/search.html'
itas2011 = 'http://www.itas2011.iitp.ru/search.html'
itas2012 = 'http://www.itas2012.iitp.ru/search.html'
itas2013 = 'http://itas2013.iitp.ru/ru/search.html'
itas2014 = 'http://itas2014.iitp.ru/ru/search.html'
itas2015 = 'http://itas2015.iitp.ru/ru/search.html'
itas2016 = 'http://itas2016.iitp.ru/ru/search.html'
itas2017 = 'http://itas2017.iitp.ru/papers/'

# %%
def load_authors_titles(url, year):
    import urllib
    from bs4 import BeautifulSoup
    
    response = urllib.request.urlopen(url)
    if response.status == 200:
        soup = BeautifulSoup(response, 'html.parser')
        
        titles = soup.find_all("a", {"class": "PaperTitle"})
        authors = soup.find_all("span", {"class": "PaperAuthors"})
        
        authors_list = []
        titles_list = []
        
        for auth, title in zip(authors, titles):
            authors_list.append(auth.get_text())
            titles_list.append(title.get_text())
            
        years = [year]*len(authors_list)
        
        return authors_list, titles_list, years
            
    else:
        print(response)
        return -1, -1, -1
    
    
def get_itas2017():    
    def get_author(text):
        try:
            all_authors, other = text.split('"other_authors"')
            other_authors, other = other.split('"first_author"')
            first_author, other = other.split('"platform"')
            other_authors, pdf= other_authors.split('"pdf"')
            other = bytes(other_authors, 'utf-8').decode('unicode_escape')
            first = bytes(first_author, 'utf-8').decode('unicode_escape')

            all_authors = []
            for f in first.split('"'):
                if len(f) > 5:
                    all_authors.append(f)

            for o in other.split('"'):
                if len(o) > 7:
                    all_authors.append(o)
            return all_authors
        except:
            return []
    data = []
    authors=[]
    response = urllib.request.urlopen(itas2017)
    soup = BeautifulSoup(response, 'html.parser')
    papers = soup.text.split('"id"')
    
    for idx,p in enumerate(papers):
        try:
            info = p.split('"abstract"')[1].split('"title"')[1]
            info2 = info.split('"all_authors"')
            title = bytes(info2[0], 'utf-8').decode('unicode_escape')
            for t in title.split('"'):
                if len(t)> 7:
                    main_title = t
            data.append(main_title)#(title)
            first_author = get_author(info2[1])
            authors.append(first_author)
        except:
            pass
        
    #authors[40], authors[42], authors[77], authors[102]
    #([], [], [], [])
    
    authors[40] = ['Анастасия Жарикова']
    authors[42] = ['Igor Zhilin', 'Victor Zyablov']
    authors[77] = ['Дарья Николаева', 'Софья Гарушянц']
    authors[102] = ['Nadezhda Terekhanova']
    
    _authors = []
    for auth in authors:
        _authors.append(', '.join(auth))
    
    return data, _authors


def process_authors(auth):
    a = []
    auth = auth.strip()
    for x in auth.split(','):
        a.append(x.strip())
    return a

# %% [markdown]
# ## Store info in DataFrame, combine all years

# %%
authors, titles, years = load_authors_titles(itas2010, 2010)

itas_all = pd.DataFrame(data={'authors': authors,
                          'titles':titles,
                          'year':years}, 
                    columns=[['authors', 'titles', 'year']])

for url,year in zip([itas2011, itas2012, itas2013, itas2014, itas2015, itas2016],
                   [2011, 2012, 2013, 2014, 2015, 2016]):

    authors, titles, years = load_authors_titles(url, year)

    itas = pd.DataFrame(data={'authors': authors,
                              'titles':titles,
                              'year':years}, 
                        columns=[['authors', 'titles', 'year']])

    itas_all = pd.concat([itas_all, itas])

# %%
titles, authors = get_itas2017()

# %%
years = [2017]*113
itas = pd.DataFrame(data={'authors': authors,
                              'titles':titles,
                              'year':years}, 
                        columns=[['authors', 'titles', 'year']])
itas_all = pd.concat([itas_all, itas])

# %%
itas_all.drop_duplicates(inplace=True)

# %%
authors = []
titles = []
years = []
for row in itas_all.iterrows():
    #print(type(row))
    #print(row[1].authors)
    article_authors = process_authors(row[1].authors)
    for auth in article_authors:
        authors.append(auth)
        titles.append(row[1].titles)
        years.append(row[1].year)

# %%
itas = pd.DataFrame(data={'author':authors,
                   'title':titles,
                   'year':years}, columns=[['author', 'title', 'year']])

# %%
itas.iloc[[678, 1114, 1199, 1964]].values
# Out:
# array([['',
#         'Количественное исследование активности центральных зрительных нейронов лягушки в зависимости от угловой скорости движения внешнего раздражителя ',
#         2012],
#        ['',
#         'НКРЯ: о некоторых различиях в описании морфологии разных частей корпуса и об автоматическом построении синтаксических структур с учетом заранее известных морфологических характеристик ',
#         2014],
#        ['',
#         'Использование критерия Отсу в пространстве геометрических разрезов на примере задачи поиска линии горизонта ',
#         2014],
#        ['',
#         'Reasoning over Knowledge-based Generation of Situations in Context Spaces to Reduce Food Waste ',
#         2016]], dtype=object)

# %%
# itas[itas.title == 'Количественное исследование активности центральных зрительных нейронов лягушки в зависимости от угловой скорости движения внешнего раздражителя ']
# Третий автор Владимир Антонинович Бастаков
itas = itas.set_value(678, 'author', 'Бастаков В.А.')

# %%
# itas[itas.title == 'НКРЯ: о некоторых различиях в описании морфологии разных частей корпуса и об автоматическом построении синтаксических структур с учетом заранее известных морфологических характеристик ']
# Третий автор Виктор Сизов
itas = itas.set_value(1114, 'author', 'Сизов В.')

# %%
# itas[itas.title == 'Использование критерия Отсу в пространстве геометрических разрезов на примере задачи поиска линии горизонта ']
# Третий автор Дарья Крохина
itas = itas.set_value(1199, 'author', 'Крохина Д.')

# %%
# itas[itas.title == 'Reasoning over Knowledge-based Generation of Situations in Context Spaces to Reduce Food Waste ']
# Четвертый автор Sylvain Kubler
itas = itas.set_value(1964, 'author', 'Sylvain Kubler')

# %%
itas.head()
# Out:
#               author                                              title  year
# 0       Алексей Адов  Оптимальный речевой кодек для VoIP в децентрал...  2010
# 1     Кирилл Андреев  Оптимальный речевой кодек для VoIP в децентрал...  2010
# 2        Павел Бойко  Оптимальный речевой кодек для VoIP в децентрал...  2010
# 3   Александр Панчин  Зависимость мутационных процессов в геноме чел...  2010
# 4  Сергей Митрофанов  Зависимость мутационных процессов в геноме чел...  2010

# %% [markdown]
# ## Process authors -> split into names and surnames

# %%
def split_author_names(author):
    
    name = author.split()
    
    if len(name) == 1:
        first_name = author
        second_name = author
        
        return first_name, second_name
    elif len(name) == 3:
        first_name = author
        second_name = author
        
        return first_name, second_name
   
    # if len(name == 2)
    
    name1 = name[0]
    name2 = name[1]

    if '.' in name1:
        first_name = name1
        second_name = name2
    elif '.' in name2:
        second_name = name1
        first_name = name2
    else:
        first_name = name1
        second_name = name2
        
    return first_name, second_name

# %%
# for idx, val in enumerate(itas.author.values):
# #     if len(val.split(' ')) != 2:
# #         print(idx, val, len(val.split(' ')))
#     print(val.split(' '))

# %%
first_name = []
second_name = []
for auth in itas.author.values:
    name1, name2 = split_author_names(auth)
    first_name.append(name1)
    second_name.append(name2)
    
itas['Name'] = first_name
itas['Surname'] = second_name

# %%
itas[['Name', 'Surname']].drop_duplicates().sort_values(by=['Surname', 'Name'])
# Out:
#                       Name               Surname
# 1553                Hadeel                 Abdah
# 1557             Ekaterina              Abushova
# 1564                Evgeny             Akkuratov
# 1574                Evgeni               Aksenov
# 1571              Vladimir               Aksenov
# 2191                  Amin              Al-Ka'bi
# 1587              Mohammed              Al-Mardi
# 1593            Abdulwahab             Al-odhari
# 1679               Smirnov             Alexander
# 1788   Alexander P. Lavrov   Alexander P. Lavrov
# 27    Alexey S. Kondrashov  Alexey S. Kondrashov
# 1594                    R.                 Amjad
# 2037      An Truong Nguyen      An Truong Nguyen
# 1599                Sergey               Andreev
# 1605               Natalia              Andreeva
# 2204                 Maria            Andrianova
# 1621                Kirill               Antonov
# 1624                    N.            Apanasenko
# 1628               Tatjana            Artamonova
# 1631                 Artem               Artemov
# 2207                German               Ashniev
# 1584             Ekaterina              Axionova
# 1708              Nadezhda             Bakhareva
# 1677                    E.                 Bakin
# 1686                Dmitry                Bankov
# 1682                Olesya              Baraniuc
# 1693                    D.               Bartoli
# 1633                    H.                 Bartz
# 1701                  Oleg                 Basov
# 1640               Nurzhan              Bazhayev
# 30                      G.               Bazykin
# 26                    G.A.               Bazykin
# 1646               Georgii               Bazykin
# 1714                  Yana              Bekeneva
# 1718                Nassim            Belmouloud
# 44                    M.G.               Belyaev
# 1734               Mikhail               Belyaev
# 1717                 Imane            Benkhelifa
# 2213            Aleksandra             Bezmenova
# 1712                    S.             Bezzateev
# 1603                Sergey             Bezzateev
# 1751                Evgeni                 Bikov
# 1754               Grigory             Bochechka
# 1561                  Olga            Bochkareva
# 1706                 Irina            Bolodurina
# 1749      Boris V. Sosunov      Boris V. Sosunov
# 1744            Konstantin             Borisenko
# 1627                Sergei              Borukhov
# 1752                Dmitri               Botvich
# 1739                    P.           Boyvalenkov
# 1940         Brian M. Luna         Brian M. Luna
# 1761             Alexander                  Bril
# 2459             Ekaterina              Budanova
# 1766               Mikhail             Buinevich
# 43                    E.V.               Burnaev
# 1556             Ekaterina                Burova
# 1562             Valentina              Burskaya
# 1555                 Paulo              Carvalho
# 1560                Andrei               Chaplin
# 1915                Alexey               Chernov
# 2134                  Zoya          Chervontseva
# 2003               Nikolay            Chervyakov
# 2008              Sang-Hwa                 Chung
# 1694                    A.               Davydov
# 2233                 Iakov               Davydov
# 1910                 Vadim               Davydov
# 2440                Stepan               Denisov
# 1912                Julien             Dhallenne
# 2297            Viacheslav               Dikonov
# 1922               Danijel                Djosic
# 1590                 Pavel              Dmitriev
# 124               Ravcheev               Dmitriy
# 1929                 Yulia              Dodonova
# 1933              Yaroslav            Domaratsky
# 1740                    P.               Dragnev
# 1916                 Pavel          Dvurechensky
# 2171              Johannes                 Ebert
# 1945                 Maria               Efimova
# 1900                Dmitry             Efrosinin
# 1778              Vladimir               Egorkin
# 1882                    N.                Egorov
# 1934                 Elena               Egorova
# 1905  Ekaterina V. Markova  Ekaterina V. Markova
# 2098                 Frank         Emmert-Streib
# 1938             Aleksandr              Ermolaev
# 1939                Ksenia               Ershova
# 123                Klimova              Evgeniya
# 1678                    G.                Evseev
# 1785               Dmitrii                Fadeev
# 196              Alexander               Favorov
# 2176                    S.             Fedorenko
# 1563              Vsevolod             Filaretov
# 1604                Alexey             Filimonov
# 1589              Grigoriy                 Fokin
# 1870                    S.                  Foss
# 1608              Alexandr               Fotiadi
# 1987                Alexey                Frolov
# 2083                 Radek               Fujdiak
# 1845                    E.             Gabidulin
# 1786                Yuliya             Gaidamaka
# 1575                 Alina             Galichina
# 1663                   Yan               Galimov
# 1854                 Sofya           Garushyants
# 76                    M.S.               Gelfand
# 1566               Mikhail               Gelfand
# 1859             Aleksandr                Gelgor
# 1871                    G.              Georgiev
# 25      Georgii A. Bazykin    Georgii A. Bazykin
# 1876                  Kenn                Gerdes
# 131               Jennifer                Gerton
# 1878               Ioannis          Giannoulakis
# 1795                    M.           Gilmutdinov
# 1695                    M.             Giulietti
# 1884              Vladimir                Gluhov
# 1858                 Anton                Gorlov
# 1890                  Oleg          Gorodnitskii
# 1567              Vladimir             Grigoryev
# 1792               Aleksey           Grishentsev
# 1899                Sergey             Grishunin
# 1893                Sergei              Grudinin
# 1756                Andrey               Gryazev
# 1746                Andrei                Gurtov
# 1908                  Oleg              Gusikhin
# 1741                    D.                Hardin
# 1961               Alireza               Hassani
# 2082                  Jiri                 Hosek
# 729                     L.                  Hung
# 2084                 Oshdi               Hussein
# 1971                  Timo            Hämäläinen
# 1886                Oksana            Iliashenko
# 1885                  Igor                  Ilin
# 1966             Alexander            Ilyashenko
# 1959                 Maria     Indrawan-Santiago
# 1995                Leonid                Iomdin
# 1902      Irina A. Gudkova      Irina A. Gudkova
# 1817              Jaroslav             Ispolatov
# 1977             Alexander                Ivanov
# 1989                 Fedor                Ivanov
# 1982                  Ivan                Ivanov
# 1984                Sergey                Ivanov
# 2182           Jae Un Jung           Jae Un Jung
# 1913                  Prem             Jayaraman
# 1921                Srdjan              Jovkovic
# 1879             Emmanouil            Kafetzakis
# 1760                  Olga              Kalinina
# 2005                    D.                Kalita
# 2460                  Olga            Kamzolkina
# 2007                  Choi              Kanghoon
# 2327                  Anna                 Karan
# 1894               Mikhail             Karasikov
# ...                    ...                   ...
# 2498             Александр               Терешин
# 2385                 Игорь                 Тетко
# 737                     В.               Тиморин
# 691                   Т.Н.             Тимофеева
# 532                   С.П.             Тимошенко
# 2488              Светлана             Тимошенко
# 464                     И.                 Титов
# 195                   Иван                 Титов
# 1725                    А.                Ткачев
# 230                     А.              Токарчук
# 450                   Е.А.             Толмачева
# 2199                   Пол               Томпсон
# 2370             Александр               Томышев
# 222                     А.            Тоневицкий
# 88               Александр            Тоневицкий
# 465                   М.П.              Трефилов
# 66                    В.Г.                Трунов
# 422                   А.Ю.              Трушанин
# 717                     А.               Тужиков
# 1194                  А.В.               Тужиков
# 1013                  А.Е.               Тупикин
# 1517                  Э.Я.              Тюрюмина
# 1329                    С.               Ульянов
# 357                     С.                Усилин
# 1092                  С.А.                Усилин
# 172                 Сергей                Усилин
# 144              Анастасия               Утешева
# 2426                Никита                 Уткин
# 964                   Н.В.              Учителев
# 1239                    В.                Ушаков
# 2415                 Роман                Ушаков
# 165                   А.В.               Фаворов
# 2469             Александр               Фаворов
# 433                     Ю.                Фантин
# 2197                Джошуа              Фасковиц
# 265                   Д.Н.               Фахриев
# 12                   Денис               Фахриев
# 370                   Г.Г.               Федонин
# 1991                    Ф.             Федоренко
# 2412                 Федор             Федоренко
# 802                    А.А               Федоров
# 944                   А.К.               Федоров
# 741                   Р.У.             Фейзханов
# 1164                    Е.                Фертиг
# 743                   В.А.             Филаретов
# 650                   Е.С.            Филимонова
# 455                   В.Н.             Филиппова
# 730                   А.А.             Филченков
# 983                   Г.Ю.               Фисунов
# 1014                  М.В.               Фридман
# 404                     Д.               Фришман
# 360                   А.А.                Фролов
# 2235               Алексей                Фролов
# 744                     Т.               Фролова
# 1339                    Д.             Фуденберг
# 315                     Ф.              Хайтович
# 1298                    В.             Халаичева
# 1523                  Д.Я.                 Хамад
# 518                     Т.               Ханипов
# 1100                  Т.М.               Ханипов
# 175                  Тимур               Ханипов
# 1212                М.О.А.                Хегази
# 382                   Е.М.                 Хоров
# 122                Евгений                 Хоров
# 766                   С.Н.           Хорошеньких
# 955                   М.С.              Хорошкин
# 317                   Е.Е.              Храмеева
# 975                     М.                 Хушам
# 752                   Ф.Н.                 Царев
# 2277               Евгений               Цацорин
# 2492             Станислав                  Цепа
# 1999                    Д.            Цибульская
# 307                     Р.                Циммер
# 463                   И.И.               Цитович
# 194                   Иван               Цитович
# 203                  Федор               Цитович
# 182                   О.В.                   Цой
# 389                   А.М.              Цыганова
# 126                   Анна              Цыганова
# 332                   О.Н.               Цышкова
# 1163                    К.                  Чанг
# 1162                    С.                 Чевэн
# 472                   В.В.               Чепыжов
# 474                   З.С.            Червонцева
# 2495                   Зоя            Червонцева
# 1241                    М.              Червяков
# 970                     Д.              Черников
# 1056                  Т.С.                Чернов
# 2499               Тимофей                Чернов
# 473                   С.С.               Чернова
# 2279                    Ю.             Чернышова
# 2368              Григорий                Чирков
# 543                     М.              Чукалина
# 1144                  М.В.              Чукалина
# 2269                Марина              Чукалина
# 685                     Е.               Чуклина
# 924                   Е.А.               Чуклина
# 437                   В.П.               Чуланов
# 1161                    Ш.                    Ша
# 1549                  Я.Л.          Шабельникова
# 844                   Е.И.         Шагимарданова
# 1833                    А.           Шамсутдинов
# 1078                  А.А.               Шананин
# 401                   И.Б.           Шапировский
# 138                   Илья           Шапировский
# 576                   В.А.              Шарануца
# 981                   А.В.              Шарипова
# 845                   М.Р.              Шарипова
# 1285                    Л.              Шаталова
# 960                   В.В.                 Шахов
# 425                   М.А.               Шашанов
# 415                   Е.А.                  Швец
# 2300               Евгений                  Швец
# 1033                  Т.Д.           Шевеленкова
# 374                   П.В.               Шелякин
# 2496                 Денис               Шепелев
# 1189                  А.В.               Шершкус
# 53                    Л.С.              Шестаков
# 2501                   Лев              Шестаков
# 726                   А.В.                Шешкус
# 2280             Александр                Шешкус
# 204                   А.Г.              Шинкарюк
# 2502                 Борис               Широких
# 119                   А.Л.                Шишкин
# 420                   М.В.                Шкерин
# 268                     К.                 Шмитт
# 1514                    М.          Шнепс-Шнеппе
# 426                   В.Ю.               Шумилов
# 223                   Е.Н.              Шустрова
# 150                   М.И.              Щелкунов
# 1545                    Ф.         Эммерт-Стреиб
# 749                     А.               Эстеров
# 153              Ю.И.Мороз             Ю.И.Мороз
# 687                   А.Н.              Юргенсон
# 180              Никифоров                  Юрий
# 1462                    Р.                Юсупов
# 2491                Руслан                Юсупов
# 1550                    Е.                Якимов
# 336                   М.Ю.                Якимов
# 1378                  Е.Ю.              Яковлева
# 471                   А.Д.           Ялалетдинов
# 1524                  Х.Г.                  Ялда
# 469                   Е.А.                Яловая
# 1455                    Ю.                Янович
# 261                   Ю.А.                Янович
# 2186                  Юрий                Янович
# 1917                    С.              Яровенко
# 2508              Светлана              Яровенко
# 1775                    Д.               Яроцкий
# 875                   Р.С.               Яруллин
#
# [1337 rows x 2 columns]

# %%
itas.to_excel('itas_2010-2017_v2.xls')

# %%
itas.head()
# Out:
#               author                                              title  year  \
# 0       Алексей Адов  Оптимальный речевой кодек для VoIP в децентрал...  2010
# 1     Кирилл Андреев  Оптимальный речевой кодек для VoIP в децентрал...  2010
# 2        Павел Бойко  Оптимальный речевой кодек для VoIP в децентрал...  2010
# 3   Александр Панчин  Зависимость мутационных процессов в геноме чел...  2010
# 4  Сергей Митрофанов  Зависимость мутационных процессов в геноме чел...  2010
#
#         Name     Surname
# 0    Алексей        Адов
# 1     Кирилл     Андреев
# 2      Павел       Бойко
# 3  Александр      Панчин
# 4     Сергей  Митрофанов

# %%
itas[itas.title == 'Сдвиговое и полусдвиговое преобразование Хаффа: генерация быстрых вычислительных схем ']
# Out:
#                author                                              title  \
# 115    Семен Карпенко  Сдвиговое и полусдвиговое преобразование Хаффа...
# 116   Валерий Соколов  Сдвиговое и полусдвиговое преобразование Хаффа...
# 117  Дмитрий Николаев  Сдвиговое и полусдвиговое преобразование Хаффа...
# 177    Семен Карпенко  Сдвиговое и полусдвиговое преобразование Хаффа...
# 178   Валерий Соколов  Сдвиговое и полусдвиговое преобразование Хаффа...
# 179   Дмитрий Николае  Сдвиговое и полусдвиговое преобразование Хаффа...
#
#      year     Name   Surname
# 115  2010    Семен  Карпенко
# 116  2010  Валерий   Соколов
# 117  2010  Дмитрий  Николаев
# 177  2010    Семен  Карпенко
# 178  2010  Валерий   Соколов
# 179  2010  Дмитрий   Николае

# %%
itas_2 = pd.read_excel('itas_2010-2017_v3.xls')
# после ручной обработки

# %%
itas_2['author_id_new'] = itas_2.Name + ' ' + itas_2.Surname

# %%
itas_2 = itas_2.drop_duplicates()

# %%
itas_2.to_excel('data_rus_author_v4.xls')

# %%
# В данной версии содержатся все данные, (почти) все авторы приведены к русскому имени,
# к одинаковой форме (либо имя + фамилия либо инициалы + фамилия) .

# %%
a = itas_2.author_id_new.values

# %%
auth, counts = np.unique(a, return_counts=True)

# %%
order = np.argsort(counts)[::-1]
auth = auth[order]
counts = counts[order]

# %%
for a, c in zip(auth, counts):
    print(a,c)
# Out:
# Евгений Хоров 51
# Г.А. Базыкин 47
# Андрей Миронов 43
# Дмитрий Николаев 32
# А.С. Кондрашов 28
# В.В. Зяблов 26
# Михаил Беляев 25
# Евгений Бурнаев 24
# Александр Фаворов 23
# Андрей Ляхов 20
# Михаил Гельфанд 18
# Елена Ставровская 17
# Артем Красилов 16
# Дмитрий Родионов 15
# Максим Панов 15
# Антон Кирьянов 14
# П.В. Приходько 13
# Екатерина Храмеева 13
# С.А. Науменко 13
# Павел Рыбин 12
# Юрий Панчин 12
# И.В. Жилин 12
# Алексей Фролов 11
# Ирина Солопова 11
# Виктор Селионов 11
# Надежда Тереханова 11
# Дмитрий Банков 11
# Александр Сафонов 11
# Федор Иванов 11
# Юлия Додонова 11
# А.В. Гасников 11
# Ольга Бочкарева 11
# Борис Миллер 11
# Иван Коноваленко 10
# Александр Миллер 10
# Владимир Спокойный 10
# И.В. Вьюгин 10
# Юрий Янович 10
# Алексей Крещук 10
# Степан Денисов 9
# А.В. Селиверстов 9
# Руслан Солдатов 9
# А.С. Иванов 9
# Карен Степанян 9
# В.А. Любецкий 9
# Владимир Сеплярский 9
# Дмитрий Жванский 9
# Владимир Потапов 8
# Мария Логачева 8
# Антон Григорьев 8
# С.В. Виноградова 8
# П.В. Шелякин 8
# Александр Панчин 8
# Алексей Пенин 8
# Александр Кротов 8
# В.Л. Талис 7
# Зоя Червонцева 7
# И.И. Артамонова 7
# Лев Шестаков 7
# Александр Дерендяев 7
# Софья Гарушянц 7
# Елена Кузнецова 7
# Д.В. Виноградов 7
# Владимир Вьюгин 7
# Константин Северинов 7
# Ю.Д. Коростелёв 6
# А.С. Калинина 6
# Марина Чукалина 6
# Ю.В. Максимов 6
# Д.C. Осипов 6
# Анастасия Ингачева 6
# В.Г. Диконов 6
# Василий Постников 6
# С.А. Лейн 6
# Павел Бойко 6
# А.В. Артемов 6
# В.В. Чепыжов 6
# Алексей Зайцев 5
# Е.Ж. Курмангалиев 5
# Г.В. Клинк 5
# Леонид Жуков 5
# Яков Давыдов 5
# М.Э. Борисова 5
# Мария Андрианова 5
# Андрей Белогаев 5
# Алексей Попов 5
# А.Д. Казнадзей 5
# Андрей Кудинов 5
# Анастасия Жарикова 5
# Кирилл Андреев 5
# Д.Б. Малько 5
# Ф. Хайтович 5
# П.Д. Ерофеев 5
# П.Е. Двуреченский 5
# Тимур Ханипов 5
# Дмитрий Сидорчук 5
# В.Е. Прун 5
# Д.А. Равчеев 5
# Вячеслав Логинов 5
# П.В. Мазин 5
# Павел Некрасов 5
# И.А. Жаров 5
# Сергей Усилин 5
# Иван Коптелов 5
# Е.А. Крымова 5
# Матвей Хорошкин 4
# Дмитрий Петров 4
# Д.С. Кононенко 4
# Андрей Овчинников 4
# А.А. Бедринцев 4
# А.А. Гришин 4
# О.А. Вахрушева 4
# Анна Клепикова 4
# Р.О. Масленников 4
# О.А. Зверков 4
# Ольга Вахрушева 4
# Д.А. Платов 4
# М.Д. Казанов 4
# М.А. Капитонов 4
# Андрей Гладков 4
# Р.Р. Гонцов 4
# А.С. Гущин 4
# Е.А. Толмачева 4
# Светлана Тимошенко 4
# В.А. Филаретов 4
# А.Ю. Трушанин 4
# Евгений Крюк 4
# Илья Шапировский 4
# В.В. Петроченков 4
# Игорь Каргин 4
# Татьяна Неретина 4
# Егор Ершов 4
# Александр Тоневицкий 4
# Александр Шешкус 4
# Виктор Сизов 4
# Виктор Кузнецов 4
# Юлия Бибило 4
# Александра Суворикова 4
# В.С. Мухина 4
# Валерий Гитис 4
# Алексей Куреев 4
# Сергей Гладилин 4
# Georgy Slivko-Koltchik 4
# О.В. Цой 4
# Е.В. Леушкин 4
# Е.В. Лопатина 4
# Е.В. Максимова 4
# А.В. Бернштейн 3
# М.П. Трефилов 3
# А.Д. Неверов 3
# А.Д. Любин 3
# И.Г. Кобозева 3
# Александра Ахмадуллина 3
# Н.О. Бузун 3
# Александра Галицына 3
# Н.С. Мюге 3
# Надежда Потапова 3
# И.А. Суворова 3
# Алексей Ступников 3
# М.И. Щелкунов 3
# Денис Фахриев 3
# Данила Бредихин 3
# Е.В. Журавлева 3
# Анна Цыганова 3
# А.В. Головин 3
# А. Бузмаков 3
# Алексей Крошнин 3
# А.В. Заика 3
# Е.В. Гасникова 3
# Елена Величко 3
# И.И. Панин 3
# А.Б. Рахманинова 3
# А.В. Безменова 3
# К.В. Лежнина 3
# Константин Славнов 3
# Мария Баранова 3
# Андрей Кучерявый 3
# Константин Самойлов 3
# Мария Логачёва 3
# Е.Н. Гордиенко 3
# А.О. Казенников 3
# А.О. Залевский 3
# Амир Сафиуллин 3
# Алёна Иванова 3
# А.А. Никулова 3
# Е.М. Максимова 3
# А.В. Акопян 3
# К.А. Кондрашов 3
# А.В. Тужиков 3
# Л.С. Булат 3
# Максим Писов 3
# Александр Парамонов 3
# Н.А. Быкова 3
# Н.А. Любимов 3
# Иван Цитович 3
# Иван Титов 3
# Евгений Швец 3
# Дмитрий Молчанов 3
# Тимофей Чернов 3
# Сергей Макаров 3
# Р.Н. Арифулов 3
# Д.В. Волчков 3
# Ю.А. Медведева 3
# Руслан Киричек 3
# Семен Карпенко 3
# Руслан Юсупов 3
# Ю.И. Мороз 3
# Светлана Яровенко 3
# Г.Г. Стерлинг 3
# Артем Борзов 3
# С.О. Королёв 3
# В.В. Степанова 3
# Б. Рябко 3
# Аркадий Заславский 3
# Сергей Макарычев 3
# В.В. Огнивов 3
# Павел Дяченко 3
# Д.Д. Первушин 3
# Юрий Селивёрстов 3
# В.В. Бочкарёв 3
